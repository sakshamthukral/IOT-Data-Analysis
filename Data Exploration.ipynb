# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./Downloads/temp-data.csv")

# %%
data
# Out:
#                                         id  room_id/id        noted_date  \
# 0      __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30
# 1      __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30
# 2      __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29
# 3      __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29
# 4      __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29
# 5      __export__.temp_log_196125_b0fa0b41  Room Admin  08-12-2018 09:29
# 6      __export__.temp_log_196121_01544d45  Room Admin  08-12-2018 09:28
# 7      __export__.temp_log_196122_f8b80a9f  Room Admin  08-12-2018 09:28
# 8      __export__.temp_log_196111_6b7a0848  Room Admin  08-12-2018 09:26
# 9      __export__.temp_log_196112_e134aebd  Room Admin  08-12-2018 09:26
# 10     __export__.temp_log_196108_4a983c7e  Room Admin  08-12-2018 09:25
# 11     __export__.temp_log_196108_4a983c7e  Room Admin  08-12-2018 09:25
# ...

# %%
data.describe()
# Out:
#                temp
# count  97606.000000
# mean      35.053931
# std        5.699825
# min       21.000000
# 25%       30.000000
# 50%       35.000000
# 75%       40.000000
# max       51.000000

# %%
data.isnull().sum()
# Out:
# id            0
# room_id/id    0
# noted_date    0
# temp          0
# out/in        0
# dtype: int64

# %%
sns.heatmap(data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
data.noted_date.nunique()
# Out:
# 27920

# %%
data['Dates'] = pd.to_datetime(data['noted_date']).dt.date
data['Time'] = pd.to_datetime(data['noted_date']).dt.time

# %%
data.head()
# Out:
#                                     id  room_id/id        noted_date  temp  \
# 0  __export__.temp_log_196134_bd201015  Room Admin  08-12-2018 09:30    29
# 1  __export__.temp_log_196131_7bca51bc  Room Admin  08-12-2018 09:30    29
# 2  __export__.temp_log_196127_522915e3  Room Admin  08-12-2018 09:29    41
# 3  __export__.temp_log_196128_be0919cf  Room Admin  08-12-2018 09:29    41
# 4  __export__.temp_log_196126_d30b72fb  Room Admin  08-12-2018 09:29    31
#
#   out/in       Dates      Time
# 0     In  2018-08-12  09:30:00
# 1     In  2018-08-12  09:30:00
# 2    Out  2018-08-12  09:29:00
# 3    Out  2018-08-12  09:29:00
# 4     In  2018-08-12  09:29:00

# %%
data.dtypes
# Out:
# id            object
# room_id/id    object
# noted_date    object
# temp           int64
# out/in        object
# Dates         object
# Time          object
# dtype: object

# %%
data['Dates'] = pd.to_datetime(data['Dates'])

# %%
# data.dtypes

# january = data['Dates'].map(lambda x : x.month) == '01'
# Out:
# /usr/lib/python3/dist-packages/pandas/core/ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-ca58932a1ed4> in <module>()
#       1 # data.dtypes
#       2
# ----> 3 january = data['Dates'].map(lambda x : x.month) == '01'
#
# /usr/lib/python3/dist-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     877
#     878             with np.errstate(all='ignore'):
# --> 879                 res = na_op(values, other)
#     880             if is_scalar(res):
#     881                 raise TypeError('Could not compare {typ} type with Series'
#
# /usr/lib/python3/dist-packages/pandas/core/ops.py in na_op(x, y)
#     816                     result = getattr(x, name)(y)
# ...
